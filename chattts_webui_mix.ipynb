# %% [markdown]
# > 🌟 如果你觉得 ChatTTS 和 ChatTTS_colab 项目对你有帮助，请访问以下链接给它们点个星星吧！🌟
#
# - [ChatTTS 项目](https://github.com/2noise/ChatTTS)
#
# - [ChatTTS_colab 项目](https://github.com/6drf21e/ChatTTS_colab)
#
# 感谢你的支持！
#
# # 运行方法
#
# - 点击菜单栏的--代码执行程序--全部运行即可
# - 执行后在下方的日志中找到类似
#
#   Running on public URL: https://**************.gradio.live  <-这个就是可以访问的公网地址
#
# 安装包的时候提示要重启 请点**"否"**

# %%
# !git clone -q https://github.com/6drf21e/ChatTTS_colab
# %cd ChatTTS_colab
# !git clone -q https://github.com/2noise/ChatTTS
# %cd ChatTTS
# !git checkout -q e6412b1
# %cd ..
# !mv ChatTTS abc
# !mv abc/* /content/ChatTTS_colab/
# !pip install -q omegaconf vocos vector_quantize_pytorch gradio cn2an pypinyin openai jieba WeTextProcessing python-dotenv
# 启动 Gradio 有公网地址
# !python webui_mix.py --share
# Out:
# /content/ChatTTS_colab
# /content/ChatTTS_colab/ChatTTS
# /content/ChatTTS_colab
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 48.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 834.7/834.7 kB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 77.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.0 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for encodec (setup.py) ... done
# Loading ChatTTS model...
# INFO:ChatTTS.core:Download from HF: https://huggingface.co/2Noise/ChatTTS
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# Vocos.pt:   0% 0.00/54.4M [00:00<?, ?B/s]
#
# Decoder.pt:   0% 0.00/104M [00:00<?, ?B/s]
#
#
# GPT.pt:   0% 0.00/901M [00:00<?, ?B/s]
#
#
#
# DVAE_full.pt:   0% 0.00/60.4M [00:00<?, ?B/s]
#
#
#
#
# tokenizer.pt:   0% 0.00/337k [00:00<?, ?B/s]
#
#
#
#
#
# config/decoder.yaml: 100% 117/117 [00:00<00:00, 940kB/s]
# tokenizer.pt: 100% 337k/337k [00:00<00:00, 12.5MB/s]
#
#
#
#
#
# DVAE.pt:   0% 0.00/27.7M [00:00<?, ?B/s]
#
#
#
#
#
# spk_stat.pt: 100% 4.26k/4.26k [00:00<00:00, 10.4MB/s]
#
#
#
#
#
#
# config/dvae.yaml: 100% 143/143 [00:00<00:00, 732kB/s]
#
# Vocos.pt:  19% 10.5M/54.4M [00:00<00:01, 39.4MB/s]
#
#
#
#
#
# config/gpt.yaml:   0% 0.00/346 [00:00<?, ?B/s]
#
#
# config/gpt.yaml: 100% 346/346 [00:00<00:00, 37.7kB/s]
#
#
#
#
# DVAE_full.pt:  17% 10.5M/60.4M [00:00<00:01, 38.6MB/s]
#
#
#
#
#
#
# config/path.yaml: 100% 309/309 [00:00<00:00, 1.65MB/s]
#
#
# Decoder.pt:  10% 10.5M/104M [00:00<00:02, 36.8MB/s]
#
#
#
#
# DVAE.pt:  38% 10.5M/27.7M [00:00<00:00, 38.9MB/s]
#
#
#
#
#
# config/vocos.yaml: 100% 460/460 [00:00<00:00, 2.95MB/s]
#
# Vocos.pt:  39% 21.0M/54.4M [00:00<00:00, 41.6MB/s]
#
# Decoder.pt:  20% 21.0M/104M [00:00<00:01, 41.7MB/s]
#
#
#
# DVAE_full.pt:  35% 21.0M/60.4M [00:00<00:00, 40.3MB/s]
#
#
# GPT.pt:   2% 21.0M/901M [00:00<00:22, 39.4MB/s]
#
#
#
#
# DVAE.pt:  76% 21.0M/27.7M [00:00<00:00, 40.8MB/s]
#
#
#
#
# DVAE.pt: 100% 27.7M/27.7M [00:00<00:00, 42.0MB/s]
# DVAE.pt: 100% 27.7M/27.7M [00:00<00:00, 40.5MB/s]
#
#
# Decoder.pt:  30% 31.5M/104M [00:00<00:01, 42.0MB/s]
#
#
#
# Fetching 12 files:   8% 1/12 [00:00<00:10,  1.05it/s]
#
#
# GPT.pt:   3% 31.5M/901M [00:00<00:21, 41.1MB/s]
# Vocos.pt:  77% 41.9M/54.4M [00:00<00:00, 42.5MB/s]
#
# Decoder.pt:  40% 41.9M/104M [00:01<00:01, 42.4MB/s]
#
#
# GPT.pt:   5% 41.9M/901M [00:01<00:20, 42.4MB/s]
#
#
#
# DVAE_full.pt:  69% 41.9M/60.4M [00:01<00:00, 40.9MB/s]
# Vocos.pt:  96% 52.4M/54.4M [00:01<00:00, 42.3MB/s]
#
# Decoder.pt:  51% 52.4M/104M [00:01<00:01, 43.0MB/s]
#
#
#
# DVAE_full.pt:  87% 52.4M/60.4M [00:01<00:00, 42.4MB/s]
#
#
# Vocos.pt: 100% 54.4M/54.4M [00:01<00:00, 40.9MB/s]
#
#
#
#
# DVAE_full.pt: 100% 60.4M/60.4M [00:01<00:00, 41.5MB/s]
# Fetching 12 files:  17% 2/12 [00:01<00:07,  1.25it/s]
#
# Decoder.pt:  61% 62.9M/104M [00:01<00:00, 43.1MB/s]
#
#
# GPT.pt:   7% 62.9M/901M [00:01<00:19, 42.5MB/s]
#
# Decoder.pt:  71% 73.4M/104M [00:01<00:00, 42.8MB/s]
#
#
# GPT.pt:   8% 73.4M/901M [00:01<00:19, 42.5MB/s]
#
# Decoder.pt:  81% 83.9M/104M [00:01<00:00, 42.9MB/s]
#
#
# GPT.pt:   9% 83.9M/901M [00:02<00:19, 42.5MB/s]
#
# Decoder.pt:  91% 94.4M/104M [00:02<00:00, 43.0MB/s]
#
#
# GPT.pt:  10% 94.4M/901M [00:02<00:19, 41.9MB/s]
#
# Decoder.pt: 100% 104M/104M [00:02<00:00, 42.1MB/s]
# Fetching 12 files:  25% 3/12 [00:02<00:08,  1.11it/s]
#
#
# GPT.pt:  12% 105M/901M [00:02<00:18, 42.3MB/s]
#
#
# GPT.pt:  13% 115M/901M [00:02<00:18, 42.4MB/s]
#
#
# GPT.pt:  14% 126M/901M [00:02<00:18, 42.5MB/s]
#
#
# GPT.pt:  15% 136M/901M [00:03<00:17, 42.7MB/s]
#
#
# GPT.pt:  16% 147M/901M [00:03<00:17, 42.5MB/s]
#
#
# GPT.pt:  17% 157M/901M [00:03<00:17, 42.5MB/s]
#
#
# GPT.pt:  19% 168M/901M [00:03<00:17, 42.6MB/s]
#
#
# GPT.pt:  20% 178M/901M [00:04<00:16, 42.6MB/s]
#
#
# GPT.pt:  21% 189M/901M [00:04<00:16, 42.8MB/s]
#
#
# GPT.pt:  22% 199M/901M [00:04<00:16, 42.4MB/s]
#
#
# GPT.pt:  23% 210M/901M [00:04<00:16, 42.4MB/s]
#
#
# GPT.pt:  24% 220M/901M [00:05<00:15, 42.6MB/s]
#
#
# GPT.pt:  26% 231M/901M [00:05<00:15, 42.4MB/s]
#
#
# GPT.pt:  27% 241M/901M [00:05<00:15, 42.4MB/s]
#
#
# GPT.pt:  28% 252M/901M [00:05<00:15, 42.7MB/s]
#
#
# GPT.pt:  29% 262M/901M [00:06<00:14, 42.6MB/s]
#
#
# GPT.pt:  30% 273M/901M [00:06<00:14, 42.6MB/s]
#
#
# GPT.pt:  31% 283M/901M [00:06<00:14, 42.0MB/s]
#
#
# GPT.pt:  33% 294M/901M [00:06<00:14, 42.2MB/s]
#
#
# GPT.pt:  34% 304M/901M [00:07<00:14, 42.2MB/s]
#
#
# GPT.pt:  35% 315M/901M [00:07<00:13, 42.1MB/s]
#
#
# GPT.pt:  36% 325M/901M [00:07<00:13, 42.2MB/s]
#
#
# GPT.pt:  37% 336M/901M [00:07<00:13, 42.1MB/s]
#
#
# GPT.pt:  38% 346M/901M [00:08<00:13, 42.3MB/s]
#
#
# GPT.pt:  40% 357M/901M [00:08<00:12, 42.4MB/s]
#
#
# GPT.pt:  41% 367M/901M [00:08<00:12, 42.5MB/s]
#
#
# GPT.pt:  42% 377M/901M [00:08<00:12, 42.5MB/s]
#
#
# GPT.pt:  43% 388M/901M [00:09<00:12, 42.6MB/s]
#
#
# GPT.pt:  44% 398M/901M [00:09<00:11, 42.6MB/s]
#
#
# GPT.pt:  45% 409M/901M [00:09<00:11, 42.8MB/s]
#
#
# GPT.pt:  47% 419M/901M [00:09<00:11, 42.7MB/s]
#
#
# GPT.pt:  48% 430M/901M [00:10<00:11, 42.6MB/s]
#
#
# GPT.pt:  49% 440M/901M [00:10<00:10, 42.6MB/s]
#
#
# GPT.pt:  50% 451M/901M [00:10<00:10, 42.8MB/s]
#
#
# GPT.pt:  51% 461M/901M [00:10<00:10, 42.1MB/s]
#
#
# GPT.pt:  52% 472M/901M [00:11<00:10, 42.4MB/s]
#
#
# GPT.pt:  54% 482M/901M [00:11<00:09, 42.6MB/s]
#
#
# GPT.pt:  55% 493M/901M [00:11<00:09, 42.5MB/s]
#
#
# GPT.pt:  56% 503M/901M [00:11<00:09, 42.5MB/s]
#
#
# GPT.pt:  57% 514M/901M [00:12<00:09, 42.5MB/s]
#
#
# GPT.pt:  58% 524M/901M [00:12<00:08, 42.2MB/s]
#
#
# GPT.pt:  59% 535M/901M [00:12<00:08, 42.2MB/s]
#
#
# GPT.pt:  61% 545M/901M [00:12<00:08, 42.4MB/s]
#
#
# GPT.pt:  62% 556M/901M [00:13<00:08, 42.3MB/s]
#
#
# GPT.pt:  63% 566M/901M [00:13<00:07, 42.5MB/s]
#
#
# GPT.pt:  64% 577M/901M [00:13<00:07, 42.4MB/s]
#
#
# GPT.pt:  65% 587M/901M [00:13<00:07, 42.3MB/s]
#
#
# GPT.pt:  66% 598M/901M [00:14<00:07, 42.4MB/s]
#
#
# GPT.pt:  68% 608M/901M [00:14<00:06, 42.4MB/s]
#
#
# GPT.pt:  69% 619M/901M [00:14<00:06, 42.4MB/s]
#
#
# GPT.pt:  70% 629M/901M [00:14<00:06, 42.6MB/s]
#
#
# GPT.pt:  71% 640M/901M [00:15<00:06, 42.6MB/s]
#
#
# GPT.pt:  72% 650M/901M [00:15<00:05, 42.7MB/s]
#
#
# GPT.pt:  73% 661M/901M [00:15<00:05, 42.7MB/s]
#
#
# GPT.pt:  75% 671M/901M [00:15<00:05, 42.1MB/s]
#
#
# GPT.pt:  76% 682M/901M [00:16<00:05, 42.2MB/s]
#
#
# GPT.pt:  77% 692M/901M [00:16<00:04, 42.4MB/s]
#
#
# GPT.pt:  78% 703M/901M [00:16<00:04, 42.7MB/s]
#
#
# GPT.pt:  79% 713M/901M [00:16<00:04, 42.1MB/s]
#
#
# GPT.pt:  80% 724M/901M [00:17<00:04, 42.2MB/s]
#
#
# GPT.pt:  81% 734M/901M [00:17<00:03, 42.2MB/s]
#
#
# GPT.pt:  83% 744M/901M [00:17<00:03, 42.4MB/s]
#
#
# GPT.pt:  84% 755M/901M [00:17<00:03, 42.3MB/s]
#
#
# GPT.pt:  85% 765M/901M [00:18<00:03, 42.5MB/s]
#
#
# GPT.pt:  86% 776M/901M [00:18<00:02, 42.4MB/s]
#
#
# GPT.pt:  87% 786M/901M [00:18<00:02, 42.3MB/s]
#
#
# GPT.pt:  88% 797M/901M [00:18<00:02, 42.4MB/s]
#
#
# GPT.pt:  90% 807M/901M [00:19<00:02, 42.4MB/s]
#
#
# GPT.pt:  91% 818M/901M [00:19<00:01, 42.3MB/s]
#
#
# GPT.pt:  92% 828M/901M [00:19<00:01, 42.3MB/s]
#
#
# GPT.pt:  93% 839M/901M [00:19<00:01, 42.5MB/s]
#
#
# GPT.pt:  94% 849M/901M [00:20<00:01, 42.5MB/s]
#
#
# GPT.pt:  95% 860M/901M [00:20<00:00, 42.4MB/s]
#
#
# GPT.pt:  97% 870M/901M [00:20<00:00, 42.3MB/s]
#
#
# GPT.pt:  98% 881M/901M [00:20<00:00, 42.4MB/s]
#
#
# GPT.pt:  99% 891M/901M [00:21<00:00, 42.4MB/s]
#
#
# GPT.pt: 100% 901M/901M [00:21<00:00, 42.4MB/s]
# Fetching 12 files: 100% 12/12 [00:21<00:00,  1.79s/it]
# INFO:ChatTTS.core:use cuda:0
# /content/ChatTTS_colab/ChatTTS/core.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   vocos.load_state_dict(torch.load(vocos_ckpt_path))
# INFO:ChatTTS.core:vocos loaded.
# /content/ChatTTS_colab/ChatTTS/core.py:115: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dvae.load_state_dict(torch.load(dvae_ckpt_path))
# INFO:ChatTTS.core:dvae loaded.
# /content/ChatTTS_colab/ChatTTS/core.py:123: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   gpt.load_state_dict(torch.load(gpt_ckpt_path))
# /content/ChatTTS_colab/ChatTTS/core.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.pretrain_models['spk_stat'] = torch.load(spk_stat_path).to(device)
# INFO:ChatTTS.core:gpt loaded.
# /content/ChatTTS_colab/ChatTTS/core.py:139: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   decoder.load_state_dict(torch.load(decoder_ckpt_path, map_location='cpu'))
# INFO:ChatTTS.core:decoder loaded.
# /content/ChatTTS_colab/ChatTTS/core.py:144: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tokenizer = torch.load(tokenizer_path, map_location='cpu')
# INFO:ChatTTS.core:tokenizer loaded.
# INFO:ChatTTS.core:All initialized.
# INFO:httpx:HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# * Running on local URL:  http://127.0.0.1:7860
# INFO:httpx:HTTP Request: GET http://127.0.0.1:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64 "HTTP/1.1 200 OK"
# * Running on public URL: https://456aa26c18cc0eda8d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# INFO:ChatTTS.core:homophones_replacer loaded.
#   0% 0/2048 [00:00<?, ?steps/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# 100% 2048/2048 [00:13<00:00, 150.43steps/s]
# Saving audio for seed 1397, took 15.44s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:12<00:00, 160.12steps/s]
# Saving audio for seed 181, took 12.86s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:13<00:00, 152.04steps/s]
# Saving audio for seed 1518, took 13.55s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:13<00:00, 151.85steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:07<00:00, 261.97steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'?'}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:10<00:00, 198.86steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:11<00:00, 177.47steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:08<00:00, 235.91steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'2', '1'}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:11<00:00, 178.38steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:10<00:00, 203.72steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:08<00:00, 230.69steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'", '2', '0', '$'}
# 100% 2048/2048 [00:12<00:00, 167.55steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:12<00:00, 162.71steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:03<00:00, 512.71steps/s]
# Saving audio for seed 1518, took 112.10s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:13<00:00, 151.88steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:15<00:00, 134.29steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:08<00:00, 253.91steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:15<00:00, 133.95steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:04<00:00, 418.54steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:02<00:00, 938.00steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:03<00:00, 590.54steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:02<00:00, 872.11steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:02<00:00, 916.01steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:07<00:00, 278.29steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:04<00:00, 486.53steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'2', '1'}
# 100% 2048/2048 [00:08<00:00, 234.52steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'", '2', '0', '$'}
# 100% 2048/2048 [00:09<00:00, 214.79steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:12<00:00, 159.10steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:06<00:00, 331.11steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {'0', '•', '\t', "'", '1'}
# 100% 2048/2048 [00:10<00:00, 203.20steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# WARNING:ChatTTS.core:Invalid characters found! : {'\t', '•'}
# 100% 2048/2048 [00:04<00:00, 415.87steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:11<00:00, 173.81steps/s]
# Saving audio for seed 1518, took 144.27s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:13<00:00, 154.44steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:15<00:00, 132.29steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:07<00:00, 257.42steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:15<00:00, 132.60steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:06<00:00, 322.87steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:09<00:00, 208.22steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:16<00:00, 127.65steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:10<00:00, 186.87steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:08<00:00, 243.96steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:08<00:00, 253.22steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:09<00:00, 211.15steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {'2', '1'}
# 100% 2048/2048 [00:09<00:00, 226.04steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:10<00:00, 188.04steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'", '2', '0', '$'}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:12<00:00, 159.33steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:09<00:00, 208.84steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:11<00:00, 183.05steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {'4', '0', "'", '2', '1', '5'}
# 100% 2048/2048 [00:10<00:00, 194.52steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:14<00:00, 144.09steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# 100% 2048/2048 [00:09<00:00, 217.05steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:12<00:00, 164.07steps/s]
# Saving audio for seed 1518, took 223.81s
# speaker_type: seed
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
# 100% 2048/2048 [00:13<00:00, 155.90steps/s]
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Package nemo_text_processing not found!
# WARNING:ChatTTS.core:Run: conda install -c conda-forge pynini=2.1.5 && pip install nemo_text_processing
# WARNING:ChatTTS.core:Invalid characters found! : {"'"}
#   5% 105/2048 [00:02<00:41, 46.87steps/s]
